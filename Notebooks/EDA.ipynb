# %%
# %sql
SELECT * FROM dataengineering.bronze.raw_transactions
LIMIT 50;

# %% [markdown]
# We see that the column _product_name_ has inconsistent casing and whitespace that can be trimmed. _total_amount_ seems to be _quantity_ times _unit_price_ thus we can check that. The categories for _payment_method_ seems to be 'Cash', 'Debit Card', 'Credit Card', 'Google Pay' and 'Apple Pay'.
